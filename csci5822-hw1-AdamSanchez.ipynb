# %% [markdown]
# # CSCI 5822 Assignment 1
#
#
# <div class="alert alert-block alert-danger">
#
# <b>Assigned:</b> Jan 22, 2021.
#
# <b>Due:</b> Feb 5 (11:59pm, MST), on Canvas.
#
# </div>
#
# You have the option to solve the assignment in place and upload the notebook as a PDF (`via "File" -> "Download as" -> "PDF via LaTeX (.pdf)"`) file. OR, use the notebook as a worksheet and upload your answers as a separated, typed PDF file. You may get partial points if you append the notebook to that file.
#
#
# Do not forget to edit your name here.
#
# <div class="alert alert-block alert-success">
#
# <b>Name: Adam Sanchez </b>
#
# <b>Collaborated With:</b>
#
# </div>
#
# The collaboration/anti-plagiarism policy for this course can be found in the syllabus statements.
#
# The questions  provided  below will ask you to either write code or
# write answers in the form of markdown. Markdown syntax guide is here: [click here](https://www.markdownguide.org/basic-syntax/). Using markdown you can typeset formulae using latex. This way you can write nice readable answers with formulae like thus:
#
# > A Markov chain is of the form $p(x_T) \prod_{t=1}^{T-1}{p(x_t | x_{t+1})}$ for some assignment of the variables to labels $x_t$.
#
# ----
#
# We will follow the following grading rubrics.
# + 10: correct answer, work is shown and clear
# + 8: correct answer but work might be difficult to read
# + 6: incorrect answer but good attempt
# + 4: mediocre attempt or very difficult to read
# + 2: problem is written down, no attempt to solve
# + 0: problem is not written down
#
#
# __Double click anywhere on this box to find out how your instructor typeset it. Press Shift+Enter to go back.__

# %% [markdown]
# The Tasks 1-5 are from Excercises 1.1-1.6 of Barber.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 1:</b> (10 points).
#
# Prove
#
# $$p(x, y | z) = p(x | z) p(y | x, z)$$
#
# and also
#
# $$p(x | y, z) = \frac{p(y | x, z) p(x|z)}{p(y|z)} \ .$$
#
#
# </div>

# %% [markdown]
# $$p(x|z)p(y|x,z) = \frac{p(x,z)}{p(z)}\frac{p(x,y,z)}{p(x,y)} = \frac{p(x,y,z)}{p(z)} = p(x,y|z)$$
#
# ______________________________________________________________________________________________________________________
#
#
# $$\frac{p(y | x, z) p(x|z)}{p(y|z)} = \frac{\frac{p(y,x,z)}{p(x,z)}\frac{p(x,z)}{p(z)}}{\frac{p(y,z)}{p(z)}}
#                                     = \frac{\frac{p(y,x,z)}{p(z)}}{\frac{p(y,z)}{p(z)}}
#                                     = \frac{p(y,x,z)}{p(y,z)}
#                                     = p(x|y,z)$$

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 2:</b> (10 points).
#
# Prove the [Bonferroni inequality](https://en.wikipedia.org/wiki/Boole%27s_inequality#Bonferroni_inequalities)
#
# $$p(a, b) \geq p(a) + p(b) - 1 \ .$$
#
# </div>

# %% [markdown]
# Since $p(a,b)$, $p(a)$, $p(b)$ are all probabilities we know they are all less than or equal to 1.
#
# Then note: $p(a)+p(b) \leq 2$.
#
# Also note that: $1 + p(a,b) \geq p(a)+ p(b)$.
#
# So we want to show that $1 + p(a,b) \leq 2$.
#
# Since we know $p(a,b) \leq 1$ it follows that:
#
# $$1 + p(a,b) \leq 1+1 = 2$$
#
# So we can conclude that $p(a,b) \geq p(a)+p(b)-1$

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 3:</b> (10 points).
#
# Consider three variable distributions which admit the factorization
#
# $$p(a, b, c) = p(a | b) p(b |c) p(c) \ ,$$
#
# where all variables are binary. How many parameters are needed to specify distributions of this form?
#
# </div>

# %% [markdown]
# This is a Niave Bayes process so we will need $(k-1)+kd$ parameters where $k$ is the number of classes and $d$ is the number of binary attributes. In our case both $k$ and $d$ are $2$ so we will need $5$ parameters.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 4:</b> (20 points, 10 each).
#
# <b>(a)</b> There are two boxes. Box 1 contains three red and five white balls and
# box 2 contains two red and five white balls. A box is chosen at random `p(box = 1) = p(box = 2) = 0.5` and
# a ball chosen at random from this box turns out to be red. What is the posterior probability that the red ball
# came from box 1?
#
# <br>
#
# <b>(b)</b> Two balls are placed in a box as follows:
# A fair coin is tossed and a white ball is placed in the box if a head occurs, otherwise a red ball is placed in the box. The coin is tossed again and a red ball is placed in the box if a tail occurs, otherwise a white ball is placed in the box. Balls are drawn from the box three times in succession (always with replacing the drawn ball back in the box). It is found that on all three occasions a red ball is drawn. What is the probability that both balls in the box are red?
# </div>

# %% [markdown]
# #### task 4(a)
#
# $$p(B=1|R) = \frac{p(R|B=1)p(B=1)}{p(R)} = \frac{\frac{3}{8}(.5)}{\frac{5}{15}} = \frac{\frac{3}{16}}{\frac{1}{3}} = \frac{9}{16} \approx .562$$

# %% [markdown]
# #### task 4(b)
#
# $$p(RR)=p(WW)=p(RW)=p(WR) = \frac{1}{4}$$

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 5:</b> (10 points).
#
# A secret government agency has developed a scanner which determines whether a person is a terrorist. The scanner is fairly reliable; 95% of all scanned terrorists are identified as terrorists, and 95% of all upstanding citizens are identified as such. An informant tells the agency that exactly one passenger of 100 aboard an aeroplane in which you are seated is a terrorist. The police haul off the plane the first person for which the scanner tests
# positive. What is the probability that this person is a terrorist?
#
# </div>

# %% [markdown]
# Let $A$ be the event the person is a terrist. Let $B$ be the event that the person tests positive.
#
# Note:
#
# $P(A) = \frac{1}{100}$, $P(A^c) = .99$, $P(B|A) = .95$, $P(B|A^c) = 1-.95 = .05$
#
# Now:
#
# $$ P(A|B) = \frac{P(B|A)P(A)}{P(B|A)P(A)+P(B|A^c)P(A^c)} = \frac{.95(.01)}{.95(.01)+.05(.99)} \approx .161$$

# %% [markdown]
# The goal of the following tasks is to give you a bit of practice manipulating data, using Bayes' rule, and constructing a naive Bayes classifier.  Naive Bayes is described in `10.1` of [Barber](http://web4.cs.ucl.ac.uk/staff/D.Barber/textbook/200620.pdf) and understanding examples `10.1` and `10.2` of the text should help you do this assignment.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Dataset</b>.
#
# The [titanic dataset](http://www.cs.toronto.edu/~delve/data/titanic/desc.html) gives the values of four categorical attributes for each of the 2201 people on board the Titanic when it struck an iceberg and sank. The attributes are social class (first class, second class, third class, crew member), age (adult or child), gender, and whether or not the person survived. The titanic dataset is available [here](https://home.cs.colorado.edu/~mozer/Teaching/syllabi/ProbabilisticModels/homework/titanic.txt).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Preparation</b>.
#
# Build a joint probability table, like the ones we discussed in class notes, that represents the joint distribution over all variables, i.e., $Pr(\text{Gender}, \text{Age}, \text{Class}, \text{Outcome})$.  This table should have 32 entries because $\text{Gender} \in \lbrace \text{male}, \text{female} \rbrace$, $\text{Age}  \in \lbrace \text{child}, \text{adult} \rbrace$, $\text{Class}  \in \lbrace \text{1st}, \text{2nd}, \text{3rd}, \text{crew} \rbrace$, and $\text{Outcome} \in \lbrace \text{death}, \text{survival} \rbrace$.
#
# You will use the data in this table for the following tasks.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 6:</b> Probability table (20 points).
#
# Build a probability table indicating $Pr(\text{Death}\ |\ \text{Gender}, \text{Age}, \text{Class})$ for each combination of gender, age, and class. Display this table in the following way:
#
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-0pky" colspan="2">Male</th>
#     <th class="tg-0pky" colspan="2">Female</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">First</td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Second</td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Third</td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Crew</td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky"></td>
#   </tr>
# </tbody>
# </table>
#
#
#
# The rows of each table represent the different classes and the columns the different ages and genders. In each cell of the table, insert the conditional probability.
#
# After you've built the probability table, come up with a rule that uses the probabilities to predict death or survival. Then make a second table, a classification table, which lists death or survival for each feature combination. Explain the rule you chose to classify.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Hint</b>.
#
# * Since it is [not possible](https://www.tablesgenerator.com/html_tables) to create merged rows with Markdown, this [**Tables Generator**](https://www.tablesgenerator.com/html_tables) may be useful.
#
# * Be alert to the possibility of a cell containing no data.
#
# </div>

# %%
# !wget "https://home.cs.colorado.edu/~mozer/Teaching/syllabi/ProbabilisticModels/homework/titanic.txt"
# Out:
# --2021-01-27 12:13:21--  https://home.cs.colorado.edu/~mozer/Teaching/syllabi/ProbabilisticModels/homework/titanic.txt
# Resolving home.cs.colorado.edu (home.cs.colorado.edu)... 198.59.7.40
# Connecting to home.cs.colorado.edu (home.cs.colorado.edu)|198.59.7.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46932 (46K) [text/plain]
# Saving to: ‘titanic.txt’
#
# titanic.txt         100%[===================>]  45.83K  --.-KB/s    in 0.02s
#
# 2021-01-27 12:13:22 (1.83 MB/s) - ‘titanic.txt’ saved [46932/46932]

# %% [markdown]
# #### Bellow is code for creating the joint prob. tabel. For the answer to Task 6 jump down to the heading marked "Task 6"

# %%
import numpy as np
import pandas as pd

f = np.loadtxt("titanic.txt", dtype=str)

# %%
f2 = pd.DataFrame(data=f,  
                  columns = ['Class', 'Age', 'Sex', 'Surived'])

dead, surived = f2['Surived'].value_counts()
total_people = dead + surived 

####Probabilities of Surived P(S) = [P(Surived = no), P(Surived = yes), P(C=3rd)] ####
p_S = np.array([dead / total_people ,surived / total_people])


#### Creating the conditional probabilities necessary P(class,sex,age|surival) #### 
s = f2.loc[f2['Surived'] == 'yes']
num_sur, a = s.shape
d = f2.loc[f2['Surived'] == 'no'] 
num_dead, a = d.shape
p_CSA_S = np.zeros((16,2))

####################################
######## First Class Males #########
####################################


######Adults########
num_fmas, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_fmas = num_fmas / total_people

num_fmad, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_fmad = num_fmad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_fma_s = p_fmas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[0,1] = p_fma_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_fma_d = p_fmad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[0,0] = p_fma_d

######Children########
num_fmcs, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_fmcs = num_fmcs / total_people

num_fmcd, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_fmcd = num_fmcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_fmc_s = p_fmcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[1,1] = p_fmc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_fmc_d = p_fmcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[1,0] = p_fmc_d

#####################################
######## First Class Females ########
#####################################
######Adults########
num_ffas, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_ffas = num_ffas / total_people
num_ffad, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_ffad = num_ffad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_ffa_s = p_ffas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[2,1] = p_ffa_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_ffa_d = p_ffad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[2,0] = p_ffa_d

######Children########
num_ffcs, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_ffcs = num_ffcs / total_people
num_ffcd, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_ffcd = num_ffcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_ffc_s = p_ffcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[3,1] = p_ffc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_ffc_d = p_ffcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[3,0] = p_ffc_d

####################################
######## 2nd Class Males #########
####################################

######Adults########
num_fmas, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_fmas = num_fmas / total_people

num_fmad, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_fmad = num_fmad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_fma_s = p_fmas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[4,1] = p_fma_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_fma_d = p_fmad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[4,0] = p_fma_d

######Children########
num_fmcs, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_fmcs = num_fmcs / total_people

num_fmcd, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_fmcd = num_fmcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_fmc_s = p_fmcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[5,1] = p_fmc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_fmc_d = p_fmcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[5,0] = p_fmc_d

#####################################
######## 2nd Class Females ########
#####################################

num_ffas, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_ffas = num_ffas / total_people
num_ffad, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_ffad = num_ffad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_ffa_s = p_ffas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[6,1] = p_ffa_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_ffa_d = p_ffad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[6,0] = p_ffa_d

######Children########
num_ffcs, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_ffcs = num_ffcs / total_people
num_ffcd, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_ffcd = num_ffcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_ffc_s = p_ffcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[7,1] = p_ffc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_ffc_d = p_ffcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[7,0] = p_ffc_d

####################################
######## 3rd Class Males #########
####################################

######Adults########
num_fmas, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_fmas = num_fmas / total_people

num_fmad, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_fmad = num_fmad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_fma_s = p_fmas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[8,1] = p_fma_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_fma_d = p_fmad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[8,0] = p_fma_d

######Children########
num_fmcs, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_fmcs = num_fmcs / total_people

num_fmcd, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_fmcd = num_fmcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_fmc_s = p_fmcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[9,1] = p_fmc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_fmc_d = p_fmcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[9,0] = p_fmc_d

#####################################
######## 3rd Class Females ########
#####################################

num_ffas, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_ffas = num_ffas / total_people
num_ffad, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_ffad = num_ffad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_ffa_s = p_ffas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[10,1] = p_ffa_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_ffa_d = p_ffad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[10,0] = p_ffa_d

######Children########
num_ffcs, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_ffcs = num_ffcs / total_people
num_ffcd, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_ffcd = num_ffcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_ffc_s = p_ffcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[11,1] = p_ffc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_ffc_d = p_ffcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[11,0] = p_ffc_d

####################################
######## Crew Class Males #########
####################################

######Adults########
num_fmas, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_fmas = num_fmas / total_people

num_fmad, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_fmad = num_fmad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_fma_s = p_fmas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[12,1] = p_fma_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_fma_d = p_fmad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[12,0] = p_fma_d

######Children########
num_fmcs, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_fmcs = num_fmcs / total_people

num_fmcd, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'male') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_fmcd = num_fmcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_fmc_s = p_fmcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[13,1] = p_fmc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_fmc_d = p_fmcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[13,0] = p_fmc_d

#####################################
######## Crew Class Females ########
#####################################

num_ffas, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='yes')].shape
p_ffas = num_ffas / total_people
num_ffad, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult') & (f2['Surived']=='no')].shape
p_ffad = num_ffad / total_people


#P(class=1st, sex = male, age = adult | surived = true)
p_ffa_s = p_ffas / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[14,1] = p_ffa_s

#P(class=1st, sex = male, age = adult | surived = false)#
p_ffa_d = p_ffad / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[14,0] = p_ffa_d

######Children########
num_ffcs, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='yes')].shape
p_ffcs = num_ffcs / total_people
num_ffcd, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'female') & (f2['Age'] == 'child') & (f2['Surived']=='no')].shape
p_ffcd = num_ffcd / total_people

#P(class=1st, sex = male, age = child | surived = true)
p_ffc_s = p_ffcs / p_S[1]
#Updating P(class,sex,age|surival)#
p_CSA_S[15,1] = p_ffc_s

#P(class=1st, sex = male, age = child | surived = false)#
p_ffc_d = p_ffcd / p_S[0]
#Updating P(class,sex,age|surival)#
p_CSA_S[15,0] = p_ffc_d

# %%
#Now finally creating out joint probability table of P(Surival, Class, Sex, Age)


p_SCSA = p_CSA_S*p_S

joint = pd.DataFrame(data=p_SCSA,  
                  columns = ['Dead', 'Surived'])
joint = joint.rename(index={0: 'First Class Adult Male'
                            ,1:'First Class Child Male'
                            ,2:'First Class Adult Female' 
                            ,3: 'First Class Child Female' 
                            ,4: 'Second Class Adult Male' 
                            ,5: 'Second Class Child Male' 
                            ,6: 'Second Class Adult Female' 
                            ,7: 'Second Class Child Female' 
                            ,8: 'Third Class Adult Male' 
                            ,9: 'Third Class Child Male' 
                            ,10: 'Third Class Adult Female' 
                            ,11: 'Third Class Child Female' 
                            ,12: 'Crew Adult Male' 
                            ,13: 'Crew Child Male' 
                            ,14: 'Crew Adult Female'
                            ,15: 'Crew Child Female'})
joint
# Out:
#                                Dead   Surived
# First Class Adult Male     0.053612  0.025897
# First Class Child Male     0.000000  0.002272
# First Class Adult Female   0.001817  0.063607
# First Class Child Female   0.000000  0.000454
# Second Class Adult Male    0.069968  0.006361
# Second Class Child Male    0.000000  0.004998
# Second Class Adult Female  0.005906  0.036347
# Second Class Child Female  0.000000  0.005906
# Third Class Adult Male     0.175829  0.034075
# Third Class Child Male     0.015902  0.005906
# Third Class Adult Female   0.040436  0.034530
# Third Class Child Female   0.007724  0.006361
# Crew Adult Male            0.304407  0.087233
# Crew Child Male            0.000000  0.000000
# Crew Adult Female          0.001363  0.009087
# Crew Child Female          0.000000  0.000000

# %%
#Creating the delerivable for Task 6# 

#P(Death|Male,1st Class,Adult)
p_dmfa, a = joint.loc['First Class Adult Male']
num_mfa, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult')].shape
p_mfa = num_mfa / total_people
p_d_mfa = p_dmfa / p_mfa
#p_d_mfa
#P(Death|Female,1st Class,Adult)
p_dffa, a = joint.loc['First Class Adult Female']
num_ffa, a = f2.loc[(f2['Class'] == '1st') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult')].shape
p_ffa = num_ffa / total_people
p_d_ffa = p_dffa / p_ffa
#p_d_ffa
#P(Death|Male,2nd Class,Adult)
p_dmsa, a = joint.loc['Second Class Adult Male']
num_msa, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult')].shape
p_msa = num_msa / total_people
p_d_msa = p_dmsa / p_msa
#p_d_msa
#P(Death|Female,2nd Class,Adult)
p_dfsa, a = joint.loc['Second Class Adult Female']
num_fsa, a = f2.loc[(f2['Class'] == '2nd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult')].shape
p_fsa = num_fsa / total_people
p_d_fsa = p_dfsa / p_fsa
#p_d_fsa
#P(Death|Male,3rd Class,Child)
p_dmtc, a = joint.loc['Third Class Child Male']
num_mtc, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'child')].shape
p_mtc = num_mtc / total_people
p_d_mtc = p_dmtc / p_mtc
#p_d_mtc
#P(Death|Male,3rd Class,Adult)
p_dmta, a = joint.loc['Third Class Adult Male']
num_mta, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult')].shape
p_mta = num_mta / total_people
p_d_mta = p_dmta / p_mta
#p_d_mta
#P(Death|Female,3rd Class,Child)
p_dftc, a = joint.loc['Third Class Child Female']
num_ftc, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'child')].shape
p_ftc = num_ftc / total_people
p_d_ftc = p_dftc / p_ftc
#p_d_ftc
#P(Death|Female,2nd Class,Adult)
p_dfta, a = joint.loc['Third Class Adult Female']
num_fta, a = f2.loc[(f2['Class'] == '3rd') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult')].shape
p_fta = num_fta / total_people
p_d_fta = p_dfta / p_fta
#p_d_fta
#P(Death|Male,Crew,Adult)
p_dmca, a = joint.loc['Crew Adult Male']
num_mca, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'male') & (f2['Age'] == 'adult')].shape
p_mca = num_mca / total_people
p_d_mca = p_dmca / p_mca
#p_d_mca
#P(Death|Female,Crew,Adult)
p_dfca, a = joint.loc['Crew Adult Female']
num_fca, a = f2.loc[(f2['Class'] == 'crew') & (f2['Sex'] == 'female') & (f2['Age'] == 'adult')].shape
p_fca = num_fca / total_people
p_d_fca = p_dfca / p_fca

# %% [markdown]
# ### Task 6:
#
# Below is my table for $Pr(\text{Death}\ |\ \text{Gender}, \text{Age}, \text{Class})$
#
#
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-6qvv{background-color:#9698ed;border-color:#9698ed;font-weight:bold;text-align:right;vertical-align:top}
# .tg .tg-i0k7{background-color:#9698ed;border-color:#9698ed;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-i0k7"> </th>
#     <th class="tg-6qvv" colspan="2">Male</th>
#     <th class="tg-6qvv" colspan="2">Female</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">First</td>
#     <td class="tg-0pky">0.0</td>
#     <td class="tg-0pky">0.6742</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0.0</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0.0278</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Second</td>
#     <td class="tg-0pky">0.0</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0.9167</span></td>
#     <td class="tg-0pky">0.0</td>
#     <td class="tg-0pky">0.1398</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Third</td>
#     <td class="tg-0lax">0.7292</td>
#     <td class="tg-0lax"><span style="font-weight:400;font-style:normal">0.8377</span></td>
#     <td class="tg-0lax"><span style="font-weight:400;font-style:normal">0.5484</span></td>
#     <td class="tg-0lax"><span style="font-weight:400;font-style:normal">0.5394</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Crew</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax"><span style="font-weight:400;font-style:normal">0.7773</span></td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax"><span style="font-weight:400;font-style:normal">0.1304</span></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 7:</b> Build a Naive Bayes classifier (20 points).
#
#
# To build the classifier, you must first construct six one-dimensional tables:
#
#
# <ul>
#     <li>$Pr(\text{Class}\ |\ \text{death})$</li>
#     <li>$Pr(\text{Age}\ |\ \text{death})$</li>
#     <li>$Pr(\text{Gender}\ |\ \text{death})$</li>
#     <li>$Pr(\text{Class}\ |\ \text{survival})$</li>
#     <li>$Pr(\text{Age}\ |\ \text{survival})$</li>
#     <li>$Pr(\text{Gender}\ |\ \text{survival})$</li>
# </ul>
#
#
# To be clear on this notation, for $Pr(\text{Age}\ |\ \text{death})$, your table should have two rows, one for adult and one for child, and you should compute, for each age group, the probability of the deceased being in that age group. Also compute the unconditional probabilities, $Pr(\text{death})$ and $Pr(\text{survival})$, with $Pr(\text{death}) + Pr(\text{survival}) = 1$. From this information, compute $Pr(\text{death}\ |\ \text{Gender}, \text{Age}, \text{Class})$ using the Naive Bayes assumption. In addition to the probability table, build the classification table as well.
#
# </div>

# %%
# your answer to task 7

#Prob of Death and Survival
p_death = p_S[0]
p_surival = p_S[1]

##P(Class|death)##
#1st class
num_fd, a = f2.loc[(f2['Class'] == '1st') & (f2['Surived'] == 'no')].shape
p_fd = num_fd / total_people
p_f_d = p_fd / p_death
#2nd class
num_sd, a = f2.loc[(f2['Class'] == '2nd') & (f2['Surived'] == 'no')].shape
p_sd = num_sd / total_people
p_s_d = p_sd / p_death
#3rd class
num_td, a = f2.loc[(f2['Class'] == '3rd') & (f2['Surived'] == 'no')].shape
p_td = num_td / total_people
p_t_d = p_td / p_death
#Crew
num_cd, a = f2.loc[(f2['Class'] == 'crew') & (f2['Surived'] == 'no')].shape
p_cd = num_cd / total_people
p_c_d = p_cd / p_death
##
z = np.array([p_f_d, p_s_d, p_t_d, p_c_d])

pr_class_death = pd.DataFrame(data=[z],  
                  columns = ['1st', '2nd', '3rd', 'Crew'])
pr_class_death
# Out:
#         1st       2nd       3rd      Crew
# 0  0.081879  0.112081  0.354362  0.451678

# %%
##P(Age|Death)##
#Adult
num_ad, a = f2.loc[(f2['Age'] == 'adult') & (f2['Surived'] == 'no')].shape
p_ad = num_ad / total_people
p_a_d = p_ad / p_death
#Child
num_cd, a = f2.loc[(f2['Age'] == 'child') & (f2['Surived'] == 'no')].shape
p_cd = num_cd / total_people
p_c_d = p_cd / p_death
##
z = np.array([p_a_d, p_c_d])

pr_age_death = pd.DataFrame(data=[z],  
                  columns = ['Adult', 'Child'])
pr_age_death
# Out:
#       Adult     Child
# 0  0.965101  0.034899

# %%
##P(Gender|Death)##
#Male
num_md, a = f2.loc[(f2['Sex'] == 'male') & (f2['Surived'] == 'no')].shape
p_md = num_md / total_people
p_m_d = p_md / p_death
#Female
num_fd, a = f2.loc[(f2['Sex'] == 'female') & (f2['Surived'] == 'no')].shape
p_fd = num_fd / total_people
p_f_d = p_fd / p_death
##
z = np.array([p_m_d, p_f_d])

pr_gender_death = pd.DataFrame(data=[z],  
                  columns = ['Male', 'Female'])
pr_gender_death
# Out:
#        Male    Female
# 0  0.915436  0.084564

# %%
##P(Class|surival)##
#1st class
num_fs, a = f2.loc[(f2['Class'] == '1st') & (f2['Surived'] == 'yes')].shape
p_fs = num_fs / total_people
p_f_s = p_fs / p_surival
#2nd class
num_ss, a = f2.loc[(f2['Class'] == '2nd') & (f2['Surived'] == 'yes')].shape
p_ss = num_ss / total_people
p_s_s = p_ss / p_surival
#3rd class
num_ts, a = f2.loc[(f2['Class'] == '3rd') & (f2['Surived'] == 'yes')].shape
p_ts = num_ts / total_people
p_t_s = p_ts / p_surival
#Crew
num_cs, a = f2.loc[(f2['Class'] == 'crew') & (f2['Surived'] == 'yes')].shape
p_cs = num_cs / total_people
p_c_s = p_cs / p_surival
##
z = np.array([p_f_s, p_s_s, p_t_s, p_c_s])

pr_class_surival = pd.DataFrame(data=[z],  
                  columns = ['1st', '2nd', '3rd', 'Crew'])
pr_class_surival
# Out:
#         1st       2nd       3rd      Crew
# 0  0.285513  0.165963  0.250352  0.298172

# %%
##P(Age|surival)##
#Adult
num_as, a = f2.loc[(f2['Age'] == 'adult') & (f2['Surived'] == 'yes')].shape
p_as = num_as / total_people
p_a_s = p_as / p_surival
#Child
num_cs, a = f2.loc[(f2['Age'] == 'child') & (f2['Surived'] == 'yes')].shape
p_cs = num_cs / total_people
p_c_s = p_cs / p_surival
##
z = np.array([p_a_s, p_c_s])

pr_age_surival = pd.DataFrame(data=[z],  
                  columns = ['Adult', 'Child'])
pr_age_surival
# Out:
#       Adult     Child
# 0  0.919831  0.080169

# %%
##P(Gender|Surival)##
#Male
num_ms, a = f2.loc[(f2['Sex'] == 'male') & (f2['Surived'] == 'yes')].shape
p_ms = num_ms / total_people
p_m_s = p_ms / p_surival
#Female
num_fs, a = f2.loc[(f2['Sex'] == 'female') & (f2['Surived'] == 'yes')].shape
p_fs = num_fs / total_people
p_f_s = p_fs / p_surival
##
z = np.array([p_m_s, p_f_s])

pr_gender_surival = pd.DataFrame(data=[z],  
                  columns = ['Male', 'Female'])
pr_gender_surival
# Out:
#        Male    Female
# 0  0.516174  0.483826

# %%
#######P𝑟(death | Gender,Age,Class)  Niave Bayes### 

#Pr(Death|Male,Adult,1st)# 
numerator = pr_class_death.loc[0,'1st']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'1st']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_maf = numerator / denominator
#pr_death_maf

#Pr(Death|Male,Child,1st)# 
numerator = pr_class_death.loc[0,'1st']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'1st']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mcf = numerator / denominator
#pr_death_mcf

#Pr(Death|Female,Child,1st)# 
numerator = pr_class_death.loc[0,'1st']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'1st']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fcf = numerator / denominator
#pr_death_fcf

#Pr(Death|Female,Adult,1st)# 
numerator = pr_class_death.loc[0,'1st']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'1st']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_faf = numerator / denominator
#pr_death_faf

#Pr(Death|Male,Child,2nd)# 
numerator = pr_class_death.loc[0,'2nd']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'2nd']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mcs = numerator / denominator
#pr_death_mcs

#Pr(Death|Male,Adult,2nd)# 
numerator = pr_class_death.loc[0,'2nd']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'2nd']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mas = numerator / denominator
#pr_death_mas

#Pr(Death|Female,Child,2nd)# 
numerator = pr_class_death.loc[0,'2nd']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'2nd']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fcs = numerator / denominator
#pr_death_fcs

#Pr(Death|Female,Adult,2nd)# 
numerator = pr_class_death.loc[0,'2nd']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'2nd']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fas = numerator / denominator
#pr_death_fas

#Pr(Death|Male,Child,3rd)# 
numerator = pr_class_death.loc[0,'3rd']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'3rd']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mct = numerator / denominator
#pr_death_mct

#Pr(Death|Male,Adult,3rd)# 
numerator = pr_class_death.loc[0,'3rd']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'3rd']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mat = numerator / denominator
#pr_death_mat

#Pr(Death|Female,Child,3rd)# 
numerator = pr_class_death.loc[0,'2nd']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'3rd']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fct = numerator / denominator
#pr_death_fct

#Pr(Death|Female,Adult,3rd)# 
numerator = pr_class_death.loc[0,'3rd']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'3rd']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fat = numerator / denominator
#pr_death_fat

#Pr(Death|Male,Child,Crew)# 
numerator = pr_class_death.loc[0,'Crew']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'Crew']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mcc = numerator / denominator
#pr_death_mcc

#Pr(Death|Male,Adult,Crew)# 
numerator = pr_class_death.loc[0,'Crew']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Male']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'Crew']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Male']
                            *p_surival))
pr_death_mac = numerator / denominator
#pr_death_mac

#Pr(Death|Female,Child,Crew)# 
numerator = pr_class_death.loc[0,'Crew']*pr_age_death.loc[0,'Child']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'Crew']
                            *pr_age_surival.loc[0,'Child']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fcc = numerator / denominator
#pr_death_fcc

#Pr(Death|Female,Adult,Crew)# 
numerator = pr_class_death.loc[0,'Crew']*pr_age_death.loc[0,'Adult']*pr_gender_death.loc[0,'Female']*p_death
denominator = numerator + ((pr_class_surival.loc[0,'Crew']
                            *pr_age_surival.loc[0,'Adult']
                            *pr_gender_surival.loc[0,'Female']
                            *p_surival))
pr_death_fac = numerator / denominator
#pr_death_fac

# %% [markdown]
# ## Task 7
#
# Below is a table for 𝑃𝑟(death | Gender,Age,Class)  using the Naive Bayes assumption.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-6qvv{background-color:#9698ed;border-color:#9698ed;font-weight:bold;text-align:right;vertical-align:top}
# .tg .tg-i0k7{background-color:#9698ed;border-color:#9698ed;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-i0k7"> </th>
#     <th class="tg-6qvv" colspan="2">Male</th>
#     <th class="tg-6qvv" colspan="2">Female</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">First</td>
#     <td class="tg-0pky">.3169</td>
#     <td class="tg-0pky">.5279</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.0437</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.0993</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Second</td>
#     <td class="tg-0pky">.5221</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.7248</span></td>
#     <td class="tg-0pky">.0972</td>
#     <td class="tg-0pky">.2061</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Third</td>
#     <td class="tg-0pky">.6961</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.8466</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.0666</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.3523</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Crew</td>
#     <td class="tg-0pky">.7102</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.8552</span></td>
#     <td class="tg-0pky">.1945</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">.3679</span></td>
#   </tr>
# </tbody>
# </table>
#
# I have also completed a "classification table" as well where the value = 1 (i.e the person dies) if the probability value in the table above is greater than 0.5. 0 otherwise.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-6qvv{background-color:#9698ed;border-color:#9698ed;font-weight:bold;text-align:right;vertical-align:top}
# .tg .tg-i0k7{background-color:#9698ed;border-color:#9698ed;text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-i0k7"> </th>
#     <th class="tg-6qvv" colspan="2">Male</th>
#     <th class="tg-6qvv" colspan="2">Female</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky"></td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#     <td class="tg-0pky">Child</td>
#     <td class="tg-0pky">Adult</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">First</td>
#     <td class="tg-0pky">0</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Second</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky">0</td>
#     <td class="tg-0pky">0</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Third</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0</span></td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0</span></td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">Crew</td>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">1</span></td>
#     <td class="tg-0pky">0</td>
#     <td class="tg-0pky"><span style="font-weight:400;font-style:normal">0</span></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Task 8:</b> Discussion (10 points, bonus)
#
#
# The classification tables you built in Tasks 6 and 7 are not identical. Discuss the advantages/disadvantages of each table for making predictions in case of another disaster like the Titanic (assuming it occurred at the same time in history). Under what circumstances would you expect an empirical table to provide better predictions? Under what circumstances would you expect the naive Bayes  table to provide better predictions?
#
# </div>

# %% [markdown]
# I think clearly that the benefit for Niave Bayes is that the calulactations are much simplier to find than in task 6. That being said we can clearly see that there seems to be a major flaw when it comes to children. We know from the data that no first class childern or second class children died (so $Pr(\text{death}\ |\ \text{Gender}, \text{Child}, \text{1st or 2nd}) = 0$).
#
# However Niave Bayes assumes that the events of being a chid and being in first/second class are indepent so it over estimates the probability of death given these factors by just multiplying all these probabilities, i.e $Pr(\text{Gender})Pr(\text{Child})Pr(\text{1st or 2nd})Pr(\text{Death})$. Since we know $Pr(\text{Child})$ is non zero because some 3rd class children died the product will also be non-negative. Given the time period the disaster happened I do not think it safe to assume that these events are all independent, so I would suggest using the method used in task 6 to provide better predictions than Niave Bayes.
#
# That being said Niave Bayes seemed to work fairly well for adults (namely males) which makes sense becasue we know they saved mostly women and children frist then by class. I think Niave Bayes would provide better predictions if the events truly were independent.
